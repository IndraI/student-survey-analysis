# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Spanish

# %%
n = [2,3,4,5,6,7]

# %%
svm_res = [0.7193284193284194, 0.7457821457821457, 0.7446048321048321, 0.7467930999180998, 0.7436754936754937, 0.7436754936754937]
svm_res_tf_idf = [0.7370060401310401, 0.7424012080262079, 0.7434215465465466, 0.7450234325234326, 0.7436754936754937, 0.7436754936754937]

plt.plot(n, svm_res, 'o-')
plt.plot(n, svm_res_tf_idf, 'o-')
plt.xlabel('n')
plt.ylabel('accuracy')
plt.legend(['SVM n-grams', 'SVM n-grams + TF-IDF'], loc='lower right')

# %%
nb_res = [0.7411502411502411, 0.7377832377832378, 0.7360940485940486, 0.7445172445172445, 0.7436754936754937, 0.7436754936754937]
nb_res_tf_idf = [0.7436754936754937, 0.7436754936754937, 0.7436754936754937, 0.7436754936754937, 0.7436754936754937, 0.7436754936754937]

plt.plot(n, nb_res, 'o-')
plt.plot(n, nb_res_tf_idf, 'o-')
plt.legend(['n-grams', 'n-grams + TF-IDF'], loc='lower right')

# %%
l_res = [0.7462064337064337, 0.7470453407953408, 0.7470481845481844, 0.7453618391118391, 0.7436754936754937, 0.7436754936754937]
l_res_tf_idf = [0.7436754936754937, 0.7436754936754937, 0.7436754936754937, 0.7436754936754937, 0.7436754936754937, 0.7436754936754937]

plt.plot(n, l_res, 'o-')
plt.plot(n, l_res_tf_idf, 'o-')
plt.legend(['n-grams', 'n-grams + TF-IDF'], loc='upper left')

# %% [markdown]
# #### Catalan

# %%
n = [2,3,4,5]

# %%
svm_res = [0.6668967586503735, 0.6035565717759458, 0.6084567013940458, 0.6084567013940458]
svm_res_tf_idf = [0.6794754921707944, 0.6084567013940458, 0.6084567013940458, 0.6084567013940458]

plt.plot(n, svm_res, 'o-')
plt.plot(n, svm_res_tf_idf, 'o-')
plt.xlabel('n')
plt.ylabel('accuracy')
plt.legend(['n-grams', 'n-grams + TF-IDF'], loc='upper right')
